# %%
from cryptography.hazmat.backends import default_backend
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.primitives import hashes
from cryptography.hazmat.primitives.asymmetric import padding
import struct
import hashlib
import pandas as pd
import numpy as np

# %%
class Block:
    def __init__(self, data, prev_hash, encryption_key=None):
        self.data = data
        self.prev_hash = prev_hash
        self.hash = self.calc_hash()
        self.encryption_key = encryption_key

    def calc_hash(self):
        sha = hashlib.sha256()
        sha.update(self.data.encode('utf-8'))
        return sha.hexdigest()

    def encrypt_data(self):
        if self.encryption_key:
            numeric_array = self.data
            message_bytes = b''.join(struct.pack('!Q', num) for num in numeric_array)
            encrypted_message = self.encryption_key.encrypt(
                message_bytes,
                padding.OAEP(
                    mgf=padding.MGF1(algorithm=hashes.SHA256()),
                    algorithm=hashes.SHA256(),
                    label=None
                )
            )
            self.data = encrypted_message.hex()

    def decrypt_data(self):
        if self.encryption_key:
            encrypted_message = bytes.fromhex(self.data)
            decrypted_message_bytes = self.encryption_key.decrypt(
                encrypted_message,
                padding.OAEP(
                    mgf=padding.MGF1(algorithm=hashes.SHA256()),
                    algorithm=hashes.SHA256(),
                    label=None
                )
            )
            self.data = [struct.unpack('!Q', decrypted_message_bytes[i:i+8])[0] for i in range(0, len(decrypted_message_bytes), 8)]

class Blockchain:
    def __init__(self):
        self.chain = [self.calc_genesis_block()]

    def calc_genesis_block(self):
        return Block("Genesis Block", "0")

    def add_block(self, data, encryption_key=None):
        prev_block = self.chain[-1]
        new_block = Block(data, prev_block.hash, encryption_key)
        new_block.encrypt_data()  # Encrypt data before adding it to the block
        self.chain.append(new_block)

    def decrypt_block_data(self, block_index, decryption_key):
        if block_index >= 0 and block_index < len(self.chain):
            block = self.chain[block_index]
            block.encryption_key = decryption_key
            block.decrypt_data()

# %%
zone_1_data = pd.read_csv(
    r"C:\Users\arshi\OneDrive\Desktop\PH.D\Blockchain\data\Sz1n.csv")

data_to_encrypt = np.array(zone_1_data)

# Create a blockchain instance
my_blockchain = Blockchain()

# Generate an RSA key pair
private_key = rsa.generate_private_key(
    public_exponent=65537,
    key_size=2048,
    backend=default_backend()
)

public_key = private_key.public_key()

# Serialize the public key for future use (e.g., sharing with others)
public_key_bytes = public_key.public_bytes(
    encoding=serialization.Encoding.PEM,
    format=serialization.PublicFormat.SubjectPublicKeyInfo
)

# Encrypt and decrypt each block's data and print the results
for block_index in range(len(data_to_encrypt)):
    block_data = data_to_encrypt[block_index]

    # Encrypt the block's data
    encrypted_message = public_key.encrypt(
        struct.pack('f' * len(block_data), *block_data),
        padding.OAEP(
            mgf=padding.MGF1(algorithm=hashes.SHA256()),
            algorithm=hashes.SHA256(),
            label=None
        )
    )

    # Decrypt the block's data
    decrypted_bytes = private_key.decrypt(
        encrypted_message,
        padding.OAEP(
            mgf=padding.MGF1(algorithm=hashes.SHA256()),
            algorithm=hashes.SHA256(),
            label=None
        )
    )

    # Unpack the decrypted bytes back into a numeric array
    decrypted_array = struct.unpack('f' * (len(block_data)), decrypted_bytes)

    # Print the results
    print(f"Block {block_index + 1}:")
    print("Original Numeric Array:", block_data)
    print("Encrypted Message:", encrypted_message.hex())
    print("Decrypted Numeric Array:", decrypted_array)
    print()
# Out:
# Block 1:
# Original Numeric Array: [  2.427057 522.8467     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4270570278167725, 522.8466796875, 2.0, 2.0, 1.0)
#
# Block 2:
# Original Numeric Array: [  2.446274 522.886      2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4462740421295166, 522.885986328125, 2.0, 2.0, 1.0)
#
# Block 3:
# Original Numeric Array: [  2.489191 522.8467     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4891910552978516, 522.8466796875, 2.0, 2.0, 1.0)
#
# Block 4:
# Original Numeric Array: [  2.53435 522.9645    2.        2.        1.     ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5343499183654785, 522.9644775390625, 2.0, 2.0, 1.0)
#
# Block 5:
# Original Numeric Array: [  2.56926 523.4748    2.        2.        1.     ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5692598819732666, 523.4747924804688, 2.0, 2.0, 1.0)
#
# Block 6:
# Original Numeric Array: [  2.609294 523.8673     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6092939376831055, 523.8673095703125, 2.0, 2.0, 1.0)
#
# Block 7:
# Original Numeric Array: [  2.637158 524.1028     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.637157917022705, 524.102783203125, 2.0, 2.0, 1.0)
#
# Block 8:
# Original Numeric Array: [  2.652211 524.2206     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6522109508514404, 524.2205810546875, 2.0, 2.0, 1.0)
#
# Block 9:
# Original Numeric Array: [  2.655735 524.4954     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6557350158691406, 524.4954223632812, 2.0, 2.0, 1.0)
#
# Block 10:
# Original Numeric Array: [  2.64997 524.0636    2.        2.        1.     ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.649970054626465, 524.0635986328125, 2.0, 2.0, 1.0)
#
# Block 11:
# Original Numeric Array: [  2.630433 524.1028     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6304330825805664, 524.102783203125, 2.0, 2.0, 1.0)
#
# Block 12:
# Original Numeric Array: [  2.621785 523.7496     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6217849254608154, 523.7495727539062, 2.0, 2.0, 1.0)
#
# Block 13:
# Original Numeric Array: [  2.61602 523.4355    2.        2.        1.     ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6160199642181396, 523.4354858398438, 2.0, 2.0, 1.0)
#
# Block 14:
# Original Numeric Array: [  2.599366 523.043      2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5993659496307373, 523.0430297851562, 2.0, 2.0, 1.0)
#
# Block 15:
# Original Numeric Array: [  2.588476 522.729      2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5884759426116943, 522.72900390625, 2.0, 2.0, 1.0)
#
# Block 16:
# Original Numeric Array: [  2.567979 522.6505     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.567979097366333, 522.6505126953125, 2.0, 2.0, 1.0)
#
# Block 17:
# Original Numeric Array: [  2.556769 522.6897     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5567688941955566, 522.689697265625, 2.0, 2.0, 1.0)
#
# Block 18:
# Original Numeric Array: [  2.53435 522.6897    2.        2.        1.     ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5343499183654785, 522.689697265625, 2.0, 2.0, 1.0)
#
# Block 19:
# Original Numeric Array: [  2.521859 522.6505     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5218589305877686, 522.6505126953125, 2.0, 2.0, 1.0)
#
# Block 20:
# Original Numeric Array: [  2.502642 522.6897     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5026419162750244, 522.689697265625, 2.0, 2.0, 1.0)
#
# Block 21:
# Original Numeric Array: [  2.489191 522.729      2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4891910552978516, 522.72900390625, 2.0, 2.0, 1.0)
#
# Block 22:
# Original Numeric Array: [  2.473497 522.5327     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.473496913909912, 522.53271484375, 2.0, 2.0, 1.0)
#
# Block 23:
# Original Numeric Array: [  2.458764 522.886      2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.45876407623291, 522.885986328125, 2.0, 2.0, 1.0)
#
# Block 24:
# Original Numeric Array: [  2.444031 523.4355     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.444031000137329, 523.4354858398438, 2.0, 2.0, 1.0)
#
# Block 25:
# Original Numeric Array: [  2.434744 523.671      2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.434743881225586, 523.6710205078125, 2.0, 2.0, 1.0)
#
# Block 26:
# Original Numeric Array: [  2.423854 523.7496     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.423854112625122, 523.7495727539062, 2.0, 2.0, 1.0)
#
# Block 27:
# Original Numeric Array: [  2.421932 523.8281     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4219319820404053, 523.828125, 2.0, 2.0, 1.0)
#
# Block 28:
# Original Numeric Array: [  2.425776 524.2598     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4257760047912598, 524.2598266601562, 2.0, 2.0, 1.0)
#
# Block 29:
# Original Numeric Array: [  2.471575 524.1421     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4715750217437744, 524.14208984375, 2.0, 2.0, 1.0)
#
# Block 30:
# Original Numeric Array: [  2.527624 524.2598     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5276238918304443, 524.2598266601562, 2.0, 2.0, 1.0)
#
# Block 31:
# Original Numeric Array: [  2.554847 524.6523     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.554847002029419, 524.6522827148438, 2.0, 2.0, 1.0)
#
# Block 32:
# Original Numeric Array: [  2.598725 524.3383     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5987250804901123, 524.3383178710938, 2.0, 2.0, 1.0)
#
# Block 33:
# Original Numeric Array: [  2.639721 524.5346     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.639720916748047, 524.5346069335938, 2.0, 2.0, 1.0)
#
# Block 34:
# Original Numeric Array: [  2.667585 524.2991     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6675848960876465, 524.299072265625, 2.0, 2.0, 1.0)
#
# Block 35:
# Original Numeric Array: [  2.673029 524.2991     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6730289459228516, 524.299072265625, 2.0, 2.0, 1.0)
#
# Block 36:
# Original Numeric Array: [  2.653172 524.2206     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.653172016143799, 524.2205810546875, 2.0, 2.0, 1.0)
#
# Block 37:
# Original Numeric Array: [  2.629152 524.4561     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6291520595550537, 524.4561157226562, 2.0, 2.0, 1.0)
#
# Block 38:
# Original Numeric Array: [  2.622105 524.4561     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6221048831939697, 524.4561157226562, 2.0, 2.0, 1.0)
#
# Block 39:
# Original Numeric Array: [  2.619543 524.8486     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6195430755615234, 524.8485717773438, 2.0, 2.0, 1.0)
#
# Block 40:
# Original Numeric Array: [  2.606412 525.3982     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.606411933898926, 525.398193359375, 2.0, 2.0, 1.0)
#
# Block 41:
# Original Numeric Array: [  2.589117 525.3196     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5891170501708984, 525.319580078125, 2.0, 2.0, 1.0)
#
# Block 42:
# Original Numeric Array: [  2.574704 525.5159     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5747039318084717, 525.5159301757812, 2.0, 2.0, 1.0)
#
# Block 43:
# Original Numeric Array: [  2.556129 525.6729     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.556128978729248, 525.6729125976562, 2.0, 2.0, 1.0)
#
# Block 44:
# Original Numeric Array: [  2.545559 525.9084     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5455589294433594, 525.9083862304688, 2.0, 2.0, 1.0)
#
# Block 45:
# Original Numeric Array: [  2.524741 525.7907     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5247409343719482, 525.7907104492188, 2.0, 2.0, 1.0)
#
# Block 46:
# Original Numeric Array: [  2.512891 525.9084     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5128910541534424, 525.9083862304688, 2.0, 2.0, 1.0)
#
# Block 47:
# Original Numeric Array: [  2.495276 525.7122     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4952759742736816, 525.7122192382812, 2.0, 2.0, 1.0)
#
# Block 48:
# Original Numeric Array: [  2.480863 525.5944     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.480863094329834, 525.5944213867188, 2.0, 2.0, 1.0)
#
# Block 49:
# Original Numeric Array: [  2.460366 525.3196     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4603660106658936, 525.319580078125, 2.0, 2.0, 1.0)
#
# Block 50:
# Original Numeric Array: [  2.448195 525.3982     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.448194980621338, 525.398193359375, 2.0, 2.0, 1.0)
#
# Block 51:
# Original Numeric Array: [  2.431221 525.5944     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4312210083007812, 525.5944213867188, 2.0, 2.0, 1.0)
#
# Block 52:
# Original Numeric Array: [  2.420331 525.5944     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4203310012817383, 525.5944213867188, 2.0, 2.0, 1.0)
#
# Block 53:
# Original Numeric Array: [  2.420331 525.3982     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4203310012817383, 525.398193359375, 2.0, 2.0, 1.0)
#
# Block 54:
# Original Numeric Array: [  2.435384 525.7122     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4353840351104736, 525.7122192382812, 2.0, 2.0, 1.0)
#
# Block 55:
# Original Numeric Array: [  2.481504 525.6729     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.481503963470459, 525.6729125976562, 2.0, 2.0, 1.0)
#
# Block 56:
# Original Numeric Array: [  2.519617 525.5944     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5196170806884766, 525.5944213867188, 2.0, 2.0, 1.0)
#
# Block 57:
# Original Numeric Array: [  2.554847 525.5944     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.554847002029419, 525.5944213867188, 2.0, 2.0, 1.0)
#
# Block 58:
# Original Numeric Array: [  2.602569 525.5159     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.602569103240967, 525.5159301757812, 2.0, 2.0, 1.0)
#
# Block 59:
# Original Numeric Array: [  2.632995 525.5159     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6329948902130127, 525.5159301757812, 2.0, 2.0, 1.0)
#
# Block 60:
# Original Numeric Array: [  2.649329 525.5944     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6493289470672607, 525.5944213867188, 2.0, 2.0, 1.0)
#
# Block 61:
# Original Numeric Array: [  2.656375 525.5159     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.656374931335449, 525.5159301757812, 2.0, 2.0, 1.0)
#
# Block 62:
# Original Numeric Array: [  2.652211 525.1234     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6522109508514404, 525.1234130859375, 2.0, 2.0, 1.0)
#
# Block 63:
# Original Numeric Array: [  2.636838 525.2019     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.636837959289551, 525.201904296875, 2.0, 2.0, 1.0)
#
# Block 64:
# Original Numeric Array: [  2.625628 525.2411     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6256279945373535, 525.2410888671875, 2.0, 2.0, 1.0)
#
# Block 65:
# Original Numeric Array: [  2.620504 524.8094     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6205039024353027, 524.8093872070312, 2.0, 2.0, 1.0)
#
# Block 66:
# Original Numeric Array: [  2.610575 524.4561     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.610574960708618, 524.4561157226562, 2.0, 2.0, 1.0)
#
# Block 67:
# Original Numeric Array: [  2.595202 524.0243     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5952019691467285, 524.0242919921875, 2.0, 2.0, 1.0)
#
# Block 68:
# Original Numeric Array: [  2.575345 523.9458     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.575345039367676, 523.94580078125, 2.0, 2.0, 1.0)
#
# Block 69:
# Original Numeric Array: [  2.561253 523.8281     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.561253070831299, 523.828125, 2.0, 2.0, 1.0)
#
# Block 70:
# Original Numeric Array: [  2.561253 523.8281     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.561253070831299, 523.828125, 2.0, 2.0, 1.0)
#
# Block 71:
# Original Numeric Array: [  2.542677 524.1421     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5426769256591797, 524.14208984375, 2.0, 2.0, 1.0)
#
# Block 72:
# Original Numeric Array: [  2.528905 524.3383     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.528904914855957, 524.3383178710938, 2.0, 2.0, 1.0)
#
# Block 73:
# Original Numeric Array: [  2.51193 524.6131    2.        2.        1.     ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.511929988861084, 524.6130981445312, 2.0, 2.0, 1.0)
#
# Block 74:
# Original Numeric Array: [  2.497518 524.6916     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4975180625915527, 524.6915893554688, 2.0, 2.0, 1.0)
#
# Block 75:
# Original Numeric Array: [  2.473817 524.4561     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4738171100616455, 524.4561157226562, 2.0, 2.0, 1.0)
#
# Block 76:
# Original Numeric Array: [  2.463248 524.7309     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4632480144500732, 524.7308959960938, 2.0, 2.0, 1.0)
#
# Block 77:
# Original Numeric Array: [  2.44179 524.6916    2.        2.        1.     ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4417901039123535, 524.6915893554688, 2.0, 2.0, 1.0)
#
# Block 78:
# Original Numeric Array: [  2.431221 525.0842     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4312210083007812, 525.084228515625, 2.0, 2.0, 1.0)
#
# Block 79:
# Original Numeric Array: [  2.421932 525.2411     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4219319820404053, 525.2410888671875, 2.0, 2.0, 1.0)
#
# Block 80:
# Original Numeric Array: [  2.420011 525.5159     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.420011043548584, 525.5159301757812, 2.0, 2.0, 1.0)
#
# Block 81:
# Original Numeric Array: [  2.447875 525.3196     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.4478750228881836, 525.319580078125, 2.0, 2.0, 1.0)
#
# Block 82:
# Original Numeric Array: [  2.500721 526.0262     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.500720977783203, 526.0261840820312, 2.0, 2.0, 1.0)
#
# Block 83:
# Original Numeric Array: [  2.543958 526.4973     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5439579486846924, 526.497314453125, 2.0, 2.0, 1.0)
#
# Block 84:
# Original Numeric Array: [  2.570861 526.8898     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5708611011505127, 526.8897705078125, 2.0, 2.0, 1.0)
#
# Block 85:
# Original Numeric Array: [  2.614739 527.2038     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.614738941192627, 527.2037963867188, 2.0, 2.0, 1.0)
#
# Block 86:
# Original Numeric Array: [  2.645806 527.3608     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.645806074142456, 527.3607788085938, 2.0, 2.0, 1.0)
#
# Block 87:
# Original Numeric Array: [  2.665023 527.4786     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6650230884552, 527.4785766601562, 2.0, 2.0, 1.0)
#
# Block 88:
# Original Numeric Array: [  2.666944 527.7534     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6669440269470215, 527.75341796875, 2.0, 2.0, 1.0)
#
# Block 89:
# Original Numeric Array: [  2.6394 528.2244   2.       2.       1.    ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.639400005340576, 528.2244262695312, 2.0, 2.0, 1.0)
#
# Block 90:
# Original Numeric Array: [  2.620824 527.8711     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.620824098587036, 527.87109375, 2.0, 2.0, 1.0)
#
# Block 91:
# Original Numeric Array: [  2.61634 528.0281    2.        2.        1.     ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.616339921951294, 528.028076171875, 2.0, 2.0, 1.0)
#
# Block 92:
# Original Numeric Array: [  2.61602 527.7534    2.        2.        1.     ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6160199642181396, 527.75341796875, 2.0, 2.0, 1.0)
#
# Block 93:
# Original Numeric Array: [  2.609294 527.4393     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.6092939376831055, 527.4392700195312, 2.0, 2.0, 1.0)
#
# Block 94:
# Original Numeric Array: [  2.584313 527.2823     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.584312915802002, 527.2822875976562, 2.0, 2.0, 1.0)
#
# Block 95:
# Original Numeric Array: [  2.572463 527.2823     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.572463035583496, 527.2822875976562, 2.0, 2.0, 1.0)
#
# Block 96:
# Original Numeric Array: [  2.554847 527.3608     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.554847002029419, 527.3607788085938, 2.0, 2.0, 1.0)
#
# Block 97:
# Original Numeric Array: [  2.542036 526.8113     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5420360565185547, 526.811279296875, 2.0, 2.0, 1.0)
#
# Block 98:
# Original Numeric Array: [  2.520257 526.5757     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.520256996154785, 526.57568359375, 2.0, 2.0, 1.0)
#
# Block 99:
# Original Numeric Array: [  2.508407 525.8692     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.5084071159362793, 525.8692016601562, 2.0, 2.0, 1.0)
#
# Block 100:
# Original Numeric Array: [  2.491112 525.3982     2.         2.         1.      ]
# Encrypted Message: ...
# Decrypted Numeric Array: (2.491111993789673, 525.398193359375, 2.0, 2.0, 1.0)
